# %% [markdown]
# ### 1. Basic ML

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Simple Linear regression

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# load data set

df = sns.load_dataset("tips")
df.to_csv("tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# Scatter plot 
sns.scatterplot(data=df , x = "total_bill" , y = "tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=df ,x="total_bill" , y="tip")

# %%
# if x and y data type is categorical than convert into numeric 

# Select feature column from df 
x= df[["total_bill"]]

# %%
# select target column from df 

y = df["tip"]

# %%
df.total_bill.dtype  # Check data types of features
# Out:
# dtype('float64')

# %%
df.tip.dtype  # Check data types of features
# Out:
# dtype('float64')

# %%
# call or load linear regression model

model = LinearRegression()

# fit the model means train the model

model.fit(x , y)
# Out:
# LinearRegression()

# %%
model.score(x ,y)
# Out:
# 0.45661658635167657

# %%
# lets predict the tip for unkown total_bill
data = pd.DataFrame([[23.7]] , columns=["total_bill"])
model.predict(data)
# Out:
# array([3.40935068])

# %% [markdown]
# ### 2. Intermediate level ML

# %%
DF =  sns.load_dataset("titanic")
DF.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.scatterplot(data=DF , x ="age" , y="fare")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
x=DF[["age"]]

# %%
y=["embarked"]

# %%
DF.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
DF_new = DF.copy()
DF_new["age"] = DF["age"].fillna(DF["age"].mean())

# %%
DF_new["embarked"] = DF["embarked"].fillna(DF["embarked"].mode()[0])

# %%
DF_new.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
DF_new.embarked.unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
# convert categorical data into numeric
# encode embarked column

DF_new["embarked_num"] = DF_new["embarked"].map({"S" : 1 , "C" : 2 , "Q" : 3})

# %%
x=DF_new[["age" , "embarked_num" ]]

# %%
y = DF_new["fare"]

# %%
model = LinearRegression()

# %%
model.fit(x , y)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 0.012161691532801111

# %%
data = pd.DataFrame([[30 , 3]], columns=[["age" , "embarked_num" ]])
model.predict(data)
# Out:
# d:\Env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([40.18206961])

# %% [markdown]
# ## Logistic Regression

# %%
# convert survived numeric data into categorical 

DF_new["survived_c"] = DF_new["survived"].map({0:"YES" , 1:"NO"})

# %%
from sklearn.linear_model import LogisticRegression

x = DF_new[["age" , "embarked_num"]]
y = DF_new["survived_c"]

# %%
# Split data for testing and training

x_train , x_test , y_train , y_train = train_test_split(x , y , test_size=0.2 , random_state=42)

# %%
model = LogisticRegression()
model.fit(x_train , y_train)
model.score(x_train , y_train)
d = pd.DataFrame([[27,3]],  columns=[["age" , "embarked_num"]])
model.predict(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[171], line 2
#       1 model = LogisticRegression()
# ----> 2 model.fit(x_train , y_train)
#
# File d:\Env\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File d:\Env\lib\site-packages\sklearn\linear_model\_logistic.py:1222, in LogisticRegression.fit(self, X, y, sample_weight)
#    1219 else:
#    1220     _dtype = [np.float64, np.float32]
# -> 1222 X, y = validate_data(
#    1223     self,
#    1224     X,
#    1225     y,
#    1226     accept_sparse="csr",
#    1227     dtype=_dtype,
#    1228     order="C",
#    1229     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1230 )
#    1231 check_classification_targets(y)
#    1232 self.classes_ = np.unique(y)
#
# File d:\Env\lib\site-packages\sklearn\utils\validation.py:2961, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959         y = check_array(y, input_name="y", **check_y_params)
#    2960     else:
# -> 2961         X, y = check_X_y(X, y, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
#
# File d:\Env\lib\site-packages\sklearn\utils\validation.py:1389, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    (...)
#    1384     input_name="X",
#    1385 )
#    1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1389 check_consistent_length(X, y)
#    1391 return X, y
#
# File d:\Env\lib\site-packages\sklearn\utils\validation.py:475, in check_consistent_length(*arrays)
#     473 uniques = np.unique(lengths)
#     474 if len(uniques) > 1:
# --> 475     raise ValueError(
#     476         "Found input variables with inconsistent numbers of samples: %r"
#     477         % [int(l) for l in lengths]
#     478     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [712, 179]
